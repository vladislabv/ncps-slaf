# %%
# !cd .. && python setup.py install
# Out:
# running install
# /opt/conda/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /opt/conda/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing ncps.egg-info/PKG-INFO
# writing dependency_links to ncps.egg-info/dependency_links.txt
# writing requirements to ncps.egg-info/requires.txt
# writing top-level names to ncps.egg-info/top_level.txt
# reading manifest file 'ncps.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'ncps.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/ncps
# creating build/bdist.linux-x86_64/egg/ncps/tf
# copying build/lib/ncps/tf/wired_cfc_cell.py -> build/bdist.linux-x86_64/egg/ncps/tf
# copying build/lib/ncps/tf/cfc_cell.py -> build/bdist.linux-x86_64/egg/ncps/tf
# copying build/lib/ncps/tf/cfc.py -> build/bdist.linux-x86_64/egg/ncps/tf
# copying build/lib/ncps/tf/__init__.py -> build/bdist.linux-x86_64/egg/ncps/tf
# copying build/lib/ncps/tf/ltc_cell.py -> build/bdist.linux-x86_64/egg/ncps/tf
# copying build/lib/ncps/tf/mm_rnn.py -> build/bdist.linux-x86_64/egg/ncps/tf
# copying build/lib/ncps/tf/ltc.py -> build/bdist.linux-x86_64/egg/ncps/tf
# creating build/bdist.linux-x86_64/egg/ncps/paddle
# copying build/lib/ncps/paddle/ltc_cell.py -> build/bdist.linux-x86_64/egg/ncps/paddle
# copying build/lib/ncps/paddle/__init__.py -> build/bdist.linux-x86_64/egg/ncps/paddle
# creating build/bdist.linux-x86_64/egg/ncps/wirings
# copying build/lib/ncps/wirings/__init__.py -> build/bdist.linux-x86_64/egg/ncps/wirings
# copying build/lib/ncps/wirings/wirings.py -> build/bdist.linux-x86_64/egg/ncps/wirings
# creating build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/keras/ltc_cell.py -> build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/keras/cfc.py -> build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/keras/mm_rnn.py -> build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/keras/wired_cfc_cell.py -> build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/keras/cfc_cell.py -> build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/keras/__init__.py -> build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/keras/ltc.py -> build/bdist.linux-x86_64/egg/ncps/keras
# copying build/lib/ncps/__init__.py -> build/bdist.linux-x86_64/egg/ncps
# creating build/bdist.linux-x86_64/egg/ncps/datasets
# copying build/lib/ncps/datasets/__init__.py -> build/bdist.linux-x86_64/egg/ncps/datasets
# creating build/bdist.linux-x86_64/egg/ncps/datasets/tf
# copying build/lib/ncps/datasets/tf/atari_cloning.py -> build/bdist.linux-x86_64/egg/ncps/datasets/tf
# copying build/lib/ncps/datasets/tf/__init__.py -> build/bdist.linux-x86_64/egg/ncps/datasets/tf
# copying build/lib/ncps/datasets/utils.py -> build/bdist.linux-x86_64/egg/ncps/datasets
# copying build/lib/ncps/datasets/icra2020_lidar_collision_avoidance.py -> build/bdist.linux-x86_64/egg/ncps/datasets
# creating build/bdist.linux-x86_64/egg/ncps/datasets/torch
# copying build/lib/ncps/datasets/torch/__init__.py -> build/bdist.linux-x86_64/egg/ncps/datasets/torch
# copying build/lib/ncps/datasets/torch/atari_cloning.py -> build/bdist.linux-x86_64/egg/ncps/datasets/torch
# creating build/bdist.linux-x86_64/egg/ncps/torch
# copying build/lib/ncps/torch/lstm.py -> build/bdist.linux-x86_64/egg/ncps/torch
# copying build/lib/ncps/torch/cfc.py -> build/bdist.linux-x86_64/egg/ncps/torch
# copying build/lib/ncps/torch/ltc_cell.py -> build/bdist.linux-x86_64/egg/ncps/torch
# copying build/lib/ncps/torch/wired_cfc_cell.py -> build/bdist.linux-x86_64/egg/ncps/torch
# copying build/lib/ncps/torch/ltc.py -> build/bdist.linux-x86_64/egg/ncps/torch
# copying build/lib/ncps/torch/__init__.py -> build/bdist.linux-x86_64/egg/ncps/torch
# copying build/lib/ncps/torch/cfc_cell.py -> build/bdist.linux-x86_64/egg/ncps/torch
# byte-compiling build/bdist.linux-x86_64/egg/ncps/tf/wired_cfc_cell.py to wired_cfc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/tf/cfc_cell.py to cfc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/tf/cfc.py to cfc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/tf/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/tf/ltc_cell.py to ltc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/tf/mm_rnn.py to mm_rnn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/tf/ltc.py to ltc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/paddle/ltc_cell.py to ltc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/paddle/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/wirings/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/wirings/wirings.py to wirings.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/keras/ltc_cell.py to ltc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/keras/cfc.py to cfc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/keras/mm_rnn.py to mm_rnn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/keras/wired_cfc_cell.py to wired_cfc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/keras/cfc_cell.py to cfc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/keras/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/keras/ltc.py to ltc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/datasets/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/datasets/tf/atari_cloning.py to atari_cloning.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/datasets/tf/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/datasets/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/datasets/icra2020_lidar_collision_avoidance.py to icra2020_lidar_collision_avoidance.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/datasets/torch/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/datasets/torch/atari_cloning.py to atari_cloning.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/torch/lstm.py to lstm.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/torch/cfc.py to cfc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/torch/ltc_cell.py to ltc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/torch/wired_cfc_cell.py to wired_cfc_cell.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/torch/ltc.py to ltc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/torch/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ncps/torch/cfc_cell.py to cfc_cell.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying ncps.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ncps.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ncps.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ncps.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ncps.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/ncps-1.0.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing ncps-1.0.0-py3.10.egg
# Copying ncps-1.0.0-py3.10.egg to /opt/conda/lib/python3.10/site-packages
# Adding ncps 1.0.0 to easy-install.pth file
#
# Installed /opt/conda/lib/python3.10/site-packages/ncps-1.0.0-py3.10.egg
# Processing dependencies for ncps==1.0.0
# Searching for future==1.0.0
# Best match: future 1.0.0
# Adding future 1.0.0 to easy-install.pth file
# Installing futurize script to /opt/conda/bin
# Installing pasteurize script to /opt/conda/bin
#
# Using /opt/conda/lib/python3.10/site-packages
# Searching for packaging==23.1
# Best match: packaging 23.1
# Adding packaging 23.1 to easy-install.pth file
#
# Using /opt/conda/lib/python3.10/site-packages
# Finished processing dependencies for ncps==1.0.0

# %%
# !pip install pytorch_lightning==1.5
# Out:
# Collecting pytorch_lightning==1.5
#   Using cached pytorch_lightning-1.5.0-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: numpy>=1.17.2 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (1.23.5)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (2.0.0+cu117)
# Requirement already satisfied: future>=0.17.1 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (1.0.0)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (4.65.0)
# Requirement already satisfied: PyYAML>=5.1 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (6.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (2023.5.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (2.11.2)
# Collecting torchmetrics>=0.4.1 (from pytorch_lightning==1.5)
#   Using cached torchmetrics-1.4.1-py3-none-any.whl (866 kB)
# Collecting pyDeprecate==0.3.1 (from pytorch_lightning==1.5)
#   Using cached pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (23.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from pytorch_lightning==1.5) (4.11.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (3.9.1)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (2.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (1.62.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (3.6)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (3.19.6)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (3.0.2)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch_lightning==1.5) (0.40.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->pytorch_lightning==1.5) (3.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->pytorch_lightning==1.5) (1.11.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->pytorch_lightning==1.5) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->pytorch_lightning==1.5) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->pytorch_lightning==1.5) (2.0.0)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6->pytorch_lightning==1.5) (3.25.0)
# Requirement already satisfied: lit in /opt/conda/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.6->pytorch_lightning==1.5) (15.0.7)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics>=0.4.1->pytorch_lightning==1.5)
#   Using cached lightning_utilities-0.11.6-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning==1.5) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning==1.5) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning==1.5) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning==1.5) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning==1.5) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch_lightning==1.5) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->pytorch_lightning==1.5) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning==1.5) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning==1.5) (3.2.2)
# Installing collected packages: pyDeprecate, lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.11.6 pyDeprecate-0.3.1 pytorch_lightning-1.5.0 torchmetrics-1.4.1

# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data_utils
import pytorch_lightning as pl

from ncps.wirings import AutoNCP
from ncps.torch import LTC

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2024-08-24 10:33:11.628025: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
device = "cuda"

# %%
path = 'data/parquet/est_hourly.parquet'

df = pd.read_parquet(path).reset_index()[["Datetime", "AEP"]].rename(
    columns={"Datetime": "datetime", "AEP": "value"}
)
df = df.set_index("datetime")
df.head()
# Out:
#                      value
# datetime
# 1998-12-31 01:00:00    NaN
# 1998-12-31 02:00:00    NaN
# 1998-12-31 03:00:00    NaN
# 1998-12-31 04:00:00    NaN
# 1998-12-31 05:00:00    NaN

# %%
#df = df[~df.value.isna()]
subsample = df.dropna()
sorted_idx = subsample.index.sort_values()
subsample = subsample.loc[sorted_idx]
subsample = subsample[subsample.index < "2006-01-01 00:00:00"]

# %%
# Factorize the timestamps
int_sequence, unique_timestamps = pd.factorize(subsample.index)

# %%
# Min-Max Normalization
tensor_min = subsample.value.min()
tensor_max = subsample.value.max()

subsample.value = (subsample.value - tensor_min) / (tensor_max - tensor_min)

# %%
year_shift = 365
week_shift = 7
x_true = subsample.value[year_shift*24+1:]
x_shifted_year = subsample.value
x_shifted_week = subsample.value[week_shift*24:]

# %%
x_ax = list(zip(x_true, x_shifted_week, x_shifted_year))

# %%
# Factorize the timestamps
int_sequence, unique_timestamps = pd.factorize(subsample.index)
data_x = torch.Tensor(x_ax)#.view((1, -1, 1))
data_y = torch.Tensor(subsample.value[:data_x.shape[0]]).view((-1, 1))

# %%
# Let's visualize the training data
sns.set_theme()
plt.figure(figsize=(6, 4))
plt.plot(data_x[:, 0], label="Input feature 1")
plt.plot(data_x[:, 1], label="Input feature 2")
plt.plot(data_x[:, 2], label="Input feature 3")
plt.plot(data_y[:, 0], label="Target output")
#plt.ylim((-1, 1))
plt.title("Training data")
plt.legend(loc="upper right")
plt.show()

# %%
# LightningModule for training a RNNSequence module
class SequenceLearner(pl.LightningModule):
    # TODO: Iterieren Tag"
    # Cycle 0"
    # VITALI: Lücken schließen, Wochentage, Feiertage"
    # Alle Indizes müssen mit 24 multipliziert werden, da wir stündliche Auflösung haben"
    # Iteration 0: y_(-1) , y_(-7) , y_(-365) -> y_hat(0) V y_(0)"
    # Iteration 1: y_hat(0) , y_(-6) , y_(-364) -> y_hat(1) V y_(1)"
    # Iteration 2: y_hat(1) , y_(-5) , y_(-363) -> y_hat(2) V y_(2)"
    # ..."
    # Iteration 6: y_hat(5) , y_(-1) , y_(-359) -> y_hat(6) V y_(6)"
    # Cycle 1"
    # Iteration 7: y_(6) , y_(0) , y_(-358) -> y_hat(7) V y_(7)
    # ...
    # Iteration 12: y_hat(5) , y_(6) , y_(-352) -> y_hat(12) V y_(12)
    # Modell speichern?"
    def __init__(self, model, lr=0.005):
        super().__init__()
        self.model = model
        self.lr = lr

    def training_step(self, batch, batch_idx):
        x, y = batch
        x = x.to(device)
        y = y.to(device)
        x = x.view((1, -1, 3))
        y = y.view((1, -1, 1))

        loss = 0.0

        for idx in range(x.shape[1]):
            # get current row
            idx_tensor = torch.tensor([idx]).to(device)
            x_curr = torch.index_select(x, 1, idx_tensor)
            y_curr = torch.index_select(y, 1, idx_tensor)
            y_hat, _ = self.model.forward(x_curr)

            y_hat = y_hat.view_as(y_curr)
            loss += nn.MSELoss()(y_hat, y_curr)

            try:
                # replace y true with prediction
                x[0, idx + 1, 0] = y_hat.item()
            except IndexError:
                # last element of the batch reached
                pass

        self.log("train_loss", loss/y.shape[1], prog_bar=True)
        return {"loss": loss}

    def validation_step(self, batch, batch_idx):
        x, y = batch
        x = x.to(device)
        y = y.to(device)
        x = x.view((1, -1, 3))
        y = y.view((1, -1, 1))
        
        loss = 0.0

        for idx in range(x.shape[1]):
            # get current row
            idx_tensor = torch.tensor([idx]).to(device)
            x_curr = torch.index_select(x, 1, idx_tensor)
            y_curr = torch.index_select(y, 1,idx_tensor)
            y_hat, _ = self.model.forward(x_curr)
            y_hat = y_hat.view_as(y_curr)

            loss += nn.MSELoss()(y_hat, y_curr)

            try:
                # replace y true with prediction
                x[0, idx + 1, 0] = y_hat.item()
            except IndexError:
                # last element of the batch reached
                pass

        self.log("val_loss", loss/y.shape[1], prog_bar=True)
        return loss

    def test_step(self, batch, batch_idx):
        # Here we just reuse the validation_step for testing
        return self.validation_step(batch, batch_idx)

    def configure_optimizers(self):
        return optim.Adam(self.model.parameters(), lr=self.lr)

# %%
dataloader = data_utils.DataLoader(
    data_utils.TensorDataset(data_x, data_y), batch_size=7, shuffle=False, num_workers=4
)

# %%
out_features = 1
in_features = 3

wiring = AutoNCP(16, out_features)  # 16 units, 1 motor neuron

ltc_model = LTC(in_features, wiring, batch_first=True, use_swish_activation=False)
ltc_model.to(device)
learn = SequenceLearner(ltc_model, lr=0.01)
trainer = pl.Trainer(
    logger=pl.loggers.CSVLogger("log"),
    max_epochs=1,
    gradient_clip_val=1,  # Clip gradient to stabilize training
    gpus=1
)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
sns.set_style("white")
plt.figure(figsize=(6, 4))
legend_handles = wiring.draw_graph(draw_labels=True, neuron_colors={"command": "tab:cyan"})
plt.legend(handles=legend_handles, loc="upper center", bbox_to_anchor=(1, 1))
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %%
# Let's visualize how LTC initialy performs before the training
sns.set_theme()
with torch.no_grad():
    prediction = ltc_model(data_x.view(1, -1, 3).to(device))[0].cpu().numpy()
plt.figure(figsize=(6, 4))
plt.plot(data_y[:, 0], label="Target output")
plt.plot(prediction[0, :, 0], label="NCP output")
plt.ylim((-1, 1))
plt.title("Before training")
plt.legend(loc="upper right")
plt.show()

# %%
# Train the model for 400 epochs (= training steps)
trainer.fit(learn, dataloader)
# Out:
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:118: UserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn("You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [3]
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | LTC  | 1.6 K
# -------------------------------
# 1.3 K     Trainable params
# 304       Non-trainable params
# 1.6 K     Total params
# 0.006     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]

# %%
# How does the trained model now fit to the sinusoidal function?
sns.set_theme()
with torch.no_grad():
    prediction = ltc_model(data_x.view(1, -1, 3).to(device))[0].cpu().numpy()
plt.figure(figsize=(6, 4))
plt.plot(data_y[:, 0], label="Target output")
plt.plot(prediction[0, :, 0], label="NCP output")
plt.ylim((-1, 1))
plt.title("After training")
plt.legend(loc="upper right")
plt.show()

# %%
# Min-Max De-Normalization
denormalized_tensor = data_y[:, 0] * (tensor_max - tensor_min) + tensor_min
denormalized_preds = prediction[0, :, 0] * (tensor_max - tensor_min) + tensor_min

# %%
# How does the trained model now fit to the sinusoidal function?
sns.set_theme()
plt.figure(figsize=(6, 4))
plt.plot(denormalized_tensor, label="Target output")
plt.plot(denormalized_preds, label="NCP output")

plt.title("After training")
plt.legend(loc="upper right")
plt.show()
